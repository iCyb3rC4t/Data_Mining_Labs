# %%
from sklearn import datasets
iris= datasets.load_iris()
print(iris.filename)
# Out:
# C:\Users\Ammar\anaconda3\lib\site-packages\sklearn\datasets\data\iris.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline
sns.set(color_codes=True)

# %%
x = np.linspace(0 , 10, 100)

flg = plt.figure()
plt.plot(x, np.sin(x),'-')
plt.plot(x, np.cos(x),'--')

# %%
from sklearn import datasets
iris = datasets.load_iris()
df = pd.read_csv(iris.filename)
df.head(5)
# Out:
#    150    4  setosa  versicolor  virginica
# 0  5.1  3.5     1.4         0.2          0
# 1  4.9  3.0     1.4         0.2          0
# 2  4.7  3.2     1.3         0.2          0
# 3  4.6  3.1     1.5         0.2          0
# 4  5.0  3.6     1.4         0.2          0

# %%
df_with_delimiter=pd.read_csv(r'C:\Users\Ammar\anaconda3\lib\site-packages\sklearn\datasets\data\iris.csv', delimiter=',', header= None,
                             names=['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)','Variety'])

df_with_delimiter.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Variety
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df_with_delimiter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Variety            150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
df_with_delimiter.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     Variety
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
print(df_with_delimiter["Variety"].value_counts())
# Out:
# 2    50
# 1    50
# 0    50
# Name: Variety, dtype: int64

# %%
print(df.shape)
# Out:
# (150, 5)

# %%
df_with_delimiter["Variety"].hist()
# Out:
# <AxesSubplot:>

# %%
for ojha, feature in enumerate(list(df_with_delimiter.columns)[:-1]):

    fg = sns.FacetGrid(df_with_delimiter, hue='Variety', height=5)

    fg.map(sns.distplot, feature).add_legend()

    plt.show()
# Out:
# C:\Users\Ammar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Ammar\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
import seaborn as sns
sns.boxplot(x='Variety',y='petal length (cm)', data=df_with_delimiter)
plt.show()

# %%
import seaborn as sns
sns.violinplot(x='Variety',y='petal length (cm)', data=df_with_delimiter)
plt.show()

# %%
df_with_delimiter.plot(kind='scatter',x='sepal length(cm)',y='sepal width (cm)', c= 'g')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal length(cm)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-673bfc7ac9c2> in <module>
# ...

# %%
sns.set_style("whitegrid");

sns.FacetGrid(df_with_delimiter, hue="Variety", height=10) \
.map(plt.scatter, "sepal length (cm)", "sepal width (cm)") \
.add_legend();

plt.show();

# %%
sns.set_style("whitegrid");

sns.pairplot(df_with_delimiter,vars = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)','Variety'], hue = 'Variety', diag_kind = 'kde', 

       plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'}, height = 2) 

plt.show()
# Out:
# C:\Users\Ammar\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Ammar\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Ammar\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
